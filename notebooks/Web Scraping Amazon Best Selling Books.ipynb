# %%
#Importing necessary libraries
import requests
# !pip install bs4
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# Requirement already satisfied: bs4 in c:\users\jasme\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jasme\anaconda3\lib\site-packages (from bs4) (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\jasme\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (1.9.5)

# %%
df=pd.DataFrame(columns=['book_name','author_name','user_rating','book_link'])

# %%
#Function to get values from a url and appending in the dataframe

def get_data(pageno):
    url='https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_'+str(pageno)+'_books?ie=UTF8&pg='+str(pageno)
    r=requests.get(url)
    soup=BeautifulSoup(r.content,'html.parser')
    
    for d in soup.find_all('div',attrs={'class':"zg-grid-general-faceout"}):
        book_name=d.find('div',attrs={'class':"_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
        author_name=d.find('div',attrs={'class':"a-row a-size-small"})
        user_rating=d.find('span',attrs={'class':"a-icon-alt"})
        book_link=d.find('a',attrs={'class':"a-link-normal"})
        all1=[]
        if book_name is not None:
            all1.append(book_name.text)
        else:
            all1.append('NaN')
        if author_name is not None:
            all1.append(author_name.text)
        else:
            all1.append('NaN')
        if user_rating is not None:
            all1.append(user_rating.text)
        else:
            all1.append('NaN')
        if book_link is not None:
            all1.append('https://www.amazon.in'+book_link.get('href'))
        else:
            all1.appen('NaN')
        #print(all1)
        df.loc[len(df)] = all1
    return df

# %%
#getting data from first page into dataframe 
get_data(1)
# Out:
#                                             book_name  \
# 0                             The Psychology Of Money
# 1   Atomic Habits: the life-changing million-copy ...
# 2   My First Library: Boxset of 10 Board Books for...
# 3   Rich Dad Poor Dad: What the Rich Teach Their K...
# 4        Don't Believe Everything You Think (English)
# 5      KARMA: A YOGI'S GUIDE TO CRAFTING YOUR DESTINY
# 6                     Shrimad Bhagwat Geeta Yatharoop
# 7   Do It Today: Overcome procrastination, improve...
# 8                 The Power of Your Subconscious Mind
# 9   My First Book of Patterns Pencil Control: Prac...
# 10  Hindus in Hindu Rashtra (Eighth-Class Citizens...
# 11                                             Ikigai
# 12  Brain Activity Book for Kids - 200+ Activities...
# 13  Indian Polity for UPSC (English| 7th Edition) ...
# 14  NTA UGC NET /SET/JRF Paper 1, Teaching and Res...
# 15                                          Elon Musk
# 16  BlackBook of English Vocabulary March 2023 by ...
# 17                The Power of Your Subconscious Mind
# 18  Grandma's Bag of Stories: Collection of 20+ Il...
# 19  MTG Objective NCERT at your FINGERTIPS Biology...
# 20  My First Mythology Tale (Illustrated) (Set of ...
# 21            How to Win Friends and Influence People
# 22          Bhagvad Gita As It Is English New Edition
# 23  Moral Story Books for Kids (Illustrated) - Eng...
# 24  Sank Magic Practice Copybook, (4 BOOK + 10 REF...
# 25                                            You Can
# 26  World's Greatest Pack for Personal Growth and ...
# 27     Rich Dad Poor Dad ( Original & Complete) Hindi
# 28  Animal Stories for Panchtantra 84 pp English 8...
# 29  MTG International Mathematics Olympiad (IMO) W...
# 30  PW JEE Main & Advanced Physics + Chemistry + M...
# 32  https://www.amazon.in/Think-Straight-Change-yo...
# 33  https://www.amazon.in/Hidden-Hindu-Book-%E0%A4...
# 34  https://www.amazon.in/International-Mathematic...
# 35  https://www.amazon.in/Class-10th-Social-Scienc...
# 36  https://www.amazon.in/Mans-Search-Meaning-Vikt...
# 37  https://www.amazon.in/Autobiography-Yogi-Param...
# 38  https://www.amazon.in/First-1000-Words-Transpo...
# 39  https://www.amazon.in/Atomic-Habits-Badlav-Asa...
# 40  https://www.amazon.in/Writing-Fun-Set-Books-Pr...
# 41  https://www.amazon.in/Previous-Question-Chapte...
# 42  https://www.amazon.in/Colouring-Books-Kids-Col...
# 43  https://www.amazon.in/International-Mathematic...
# 44  https://www.amazon.in/Oswaal-CBSE-Class-Scienc...
# 45  https://www.amazon.in/Word-Power-Made-Norman-L...
# 46  https://www.amazon.in/Colouring-Books-Set-10/d...
# 47  https://www.amazon.in/Discipline-is-Destiny-Ma...
# 48  https://www.amazon.in/International-Mathematic...
# 49  https://www.amazon.in/Hidden-Hindu-Hindi-Trans...

# %%
#getting data from any number of pages and appending data frame of each page to the result
no_of_pages=2
df=pd.DataFrame(columns=['book_name','author_name','user_rating','book_link'])
for i in range(1,no_of_pages+1):
    df.append(get_data(i))

# %%
df
# Out:
#                                             book_name         author_name  \
# 0                             The Psychology Of Money       Morgan Housel
# 1   Atomic Habits: the life-changing million-copy ...         James Clear
# 2   My First Library: Boxset of 10 Board Books for...  Wonder House Books
# 3   Rich Dad Poor Dad: What the Rich Teach Their K...  Robert T. Kiyosaki
# 4        Don't Believe Everything You Think (English)       Joseph Nguyen
# ..                                                ...                 ...
# 95                                                NaN      Product Bundle
# 96                           THINK AND GROW RICH (PB)       Napoleon Hill
# 97                                  As a Man Thinketh         James Allen
# 98  1001 Ultimate Brain Booster Activities for 3 t...        Team Pegasus
# 99  Picture Books Collection for Early Learning (S...            E C Axus
#
#            user_rating                                          book_link
# 0   4.6 out of 5 stars  https://www.amazon.in/Psychology-Money-Morgan-...
# 1   4.6 out of 5 stars  https://www.amazon.in/Atomic-Habits-James-Clea...
# 2   4.5 out of 5 stars  https://www.amazon.in/My-First-Library-Boxset-...
# 3   4.5 out of 5 stars  https://www.amazon.in/Rich-Dad-Poor-Middle-Ann...
# 4   4.5 out of 5 stars  https://www.amazon.in/Dont-Believe-Everything-...
# ..                 ...                                                ...
# 95  4.6 out of 5 stars  https://www.amazon.in/Hidden-Hindu/dp/B0CBQ9VM...
# 96  4.4 out of 5 stars  https://www.amazon.in/Think-Grow-Rich-Napoleon...
# 97  4.4 out of 5 stars  https://www.amazon.in/As-Man-Thinketh-James-Al...
# 98  4.6 out of 5 stars  https://www.amazon.in/Ultimate-Brain-Booster-A...
# 99  4.3 out of 5 stars  https://www.amazon.in/Picture-Books-Collection...
#
# [100 rows x 4 columns]
